# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('salary.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x = df.YearsExperience
y = df.Salary

# %%
plt.scatter(x,y)
plt.plot(x,m*x+b, 'pink')

# %% [markdown]
# 1. CALCULATE SSxx

# %%
xmean = x.mean()
xmean
# Out:
# 5.3133333333333335

# %%
df['diffx'] = xmean - x

# %%
df['diffx_square']= df.diffx ** 2

# %%
SSxx = df.diffx_square.sum()
SSxx
# Out:
# 233.55466666666666

# %% [markdown]
# 2. CALCULATE SSxy

# %%
ymean = y.mean()
ymean
# Out:
# 76003.0

# %%
df['diffy'] = ymean - y

# %%
SSxy = (df.diffx * df.diffy).sum() 
SSxy
# Out:
# 2207082.8000000003

# %%
m = SSxy/SSxx
m
# Out:
# 9449.962321455077

# %%
b =ymean -m * xmean
b
df
# Out:
#     YearsExperience    Salary     diffx  diffx_square    diffy
# 0               1.1   39343.0  4.213333     17.752178  36660.0
# 1               1.3   46205.0  4.013333     16.106844  29798.0
# 2               1.5   37731.0  3.813333     14.541511  38272.0
# 3               2.0   43525.0  3.313333     10.978178  32478.0
# 4               2.2   39891.0  3.113333      9.692844  36112.0
# 5               2.9   56642.0  2.413333      5.824178  19361.0
# 6               3.0   60150.0  2.313333      5.351511  15853.0
# 7               3.2   54445.0  2.113333      4.466178  21558.0
# 8               3.2   64445.0  2.113333      4.466178  11558.0
# 9               3.7   57189.0  1.613333      2.602844  18814.0
# 10              3.9   63218.0  1.413333      1.997511  12785.0
# 11              4.0   55794.0  1.313333      1.724844  20209.0
# 12              4.0   56957.0  1.313333      1.724844  19046.0
# 13              4.1   57081.0  1.213333      1.472178  18922.0
# 14              4.5   61111.0  0.813333      0.661511  14892.0
# 15              4.9   67938.0  0.413333      0.170844   8065.0
# 16              5.1   66029.0  0.213333      0.045511   9974.0
# 17              5.3   83088.0  0.013333      0.000178  -7085.0
# 18              5.9   81363.0 -0.586667      0.344178  -5360.0
# 19              6.0   93940.0 -0.686667      0.471511 -17937.0
# 20              6.8   91738.0 -1.486667      2.210178 -15735.0
# 21              7.1   98273.0 -1.786667      3.192178 -22270.0
# 22              7.9  101302.0 -2.586667      6.690844 -25299.0
# 23              8.2  113812.0 -2.886667      8.332844 -37809.0
# 24              8.7  109431.0 -3.386667     11.469511 -33428.0
# 25              9.0  105582.0 -3.686667     13.591511 -29579.0
# 26              9.5  116969.0 -4.186667     17.528178 -40966.0
# 27              9.6  112635.0 -4.286667     18.375511 -36632.0
# 28             10.3  122391.0 -4.986667     24.866844 -46388.0
# 29             10.5  121872.0 -5.186667     26.901511 -45869.0

# %%
def predict(value):
    predict = m*value +b
    return predict

# %%
predict(70)
# Out:
# 687289.5627005241

# %%
predict(3)
# Out:
# 54142.087163033924
